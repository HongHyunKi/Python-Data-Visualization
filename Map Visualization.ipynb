# %%
# 필요한 패키지 설치 및 임포트
import folium
from folium import Marker
from folium import plugins
from folium import GeoJson
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objects as go

# %%
# 서울 스타벅스 지점 데이터 불러오기

url="https://raw.githubusercontent.com/c-karl/DA_DS_Book001/main/datasets/Starbucks_Seoul.csv"
df=pd.read_csv(url)

# 지역 구분을 위한 json 파일 불러오기
geo="https://raw.githubusercontent.com/c-karl/DA_DS_Book001/main/datasets/Seoul_Gu.json"

# 데이터 샘플 확인
df.head()
# Out:
#        name                                   address gu_name   latitude
# 0      GS타워                   서울특별시 강남구 논현로 508 (역삼동)     강남구  37.501859  \
# 1  SSG마켓도곡R  서울특별시 강남구 언주로30길 57, 타워팰리스Ⅱ F 지하1층 (도곡동)     강남구  37.490298
# 2    W-Mall                  서울특별시 금천구 디지털로 188 (가산동)     금천구  37.477305
# 3     가든파이브             서울특별시 송파구 충민로 10 (문정동) 가든파이브툴     송파구  37.478232
# 4      가락본동                서울특별시 송파구 송파대로30길 13 (가락동)     송파구  37.494895
#
#     longitude
# 0  127.037278
# 1  127.054895
# 2  126.887691
# 3  127.119370
# 4  127.118785

# %% [markdown]
# 데이터를 판다스 데이터 프레임으로 불러온 다음 확인한다. 각 스타벅스 지점명과 주소, 해당 구, 위도와 경도 정보가 있는 것을 확인할 수 있다. 그리고 지도 위에 시각화를 해야 하기 때문에 서울 각 구의 경계를 표현해줄 수 있는 json 파일도 불러온다.

# %%
# 기본 지도 시각화 (서울의 위도, 경도 입력)

m = folium.Map(location=[37.541, 126.986], zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e03c87b0ab61b1552aa97e49ffbb95e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e03c87b0ab61b1552aa97e49ffbb95e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e03c87b0ab61b1552aa97e49ffbb95e6 = L.map(
#                 &quot;map_e03c87b0ab61b1552aa97e49ffbb95e6&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c22c8955b267923ebd428e458acd0aad = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e03c87b0ab61b1552aa97e49ffbb95e6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 가장 기본적인 지도를 시각화 했다. location= 옵션을 사용하여 나타내고자 하는 지역의 위도와 경도를 입력한다. 그리고 처음 화면에서 어느 정도의 확대 수준으로 시각화 할지는 zoom_start= 옵션을 사용한다.

# %%
# 지도 형태 변경
m = folium.Map(location=[37.541, 126.986], tiles='Stamen Toner', zoom_start=12)

# 원하는 좌표에 반경(radius) 표시 (남산)
folium.CircleMarker([37.5538, 126.9810],radius=50, 
                    popup='Laurelhurst Park', color='#3246cc', 
                    fill_color='#3246cc').add_to(m)

# 원하는 좌표에 포인트 표시 (남산)
folium.Marker([37.5538, 126.9810], popup='The Waterfront').add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86b4f2c846857c1522372c74bcd443c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86b4f2c846857c1522372c74bcd443c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86b4f2c846857c1522372c74bcd443c3 = L.map(
#                 &quot;map_86b4f2c846857c1522372c74bcd443c3&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c719920b8ba18d2f2f240822187873f6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86b4f2c846857c1522372c74bcd443c3);
#
#
#             var circle_marker_3d565da3a64bc6d6decb0a132f57f781 = L.circleMarker(
#                 [37.5538, 126.981],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3246cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3246cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86b4f2c846857c1522372c74bcd443c3);
#
#
#         var popup_b9ccba54453cbad730fe070fecd20cd8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_174ea75b7d793602d39aad24831b5855 = $(`&lt;div id=&quot;html_174ea75b7d793602d39aad24831b5855&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#                 popup_b9ccba54453cbad730fe070fecd20cd8.setContent(html_174ea75b7d793602d39aad24831b5855);
#
#
#
#         circle_marker_3d565da3a64bc6d6decb0a132f57f781.bindPopup(popup_b9ccba54453cbad730fe070fecd20cd8)
#         ;
#
#
#
#
#             var marker_1c0454fcb82f7dfb8a4f5f912fa7f19c = L.marker(
#                 [37.5538, 126.981],
#                 {}
#             ).addTo(map_86b4f2c846857c1522372c74bcd443c3);
#
#
#         var popup_3b921b486d81dae457fdd2cd0edc4b28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23249aeb679e1790f1125ebb84dd6216 = $(`&lt;div id=&quot;html_23249aeb679e1790f1125ebb84dd6216&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_3b921b486d81dae457fdd2cd0edc4b28.setContent(html_23249aeb679e1790f1125ebb84dd6216);
#
#
#
#         marker_1c0454fcb82f7dfb8a4f5f912fa7f19c.bindPopup(popup_3b921b486d81dae457fdd2cd0edc4b28)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 기본 지도는 옵션을 통하여 형태를 다양하게 바꿀 수 있고 다양한 표시를 삽입할 수 있다. tiles= 옵션은 지도의 형태를 변경해 준다. 예시에서 사용한 Stamen Toner 외에도 Stamen Watercolor, Stamen Terrain, Cartodb Positron, Cartodb Dark_matter 등의 옵션이 있다. 그리고 CircleMarker()와 Marker() 함수를 통해 남산의 위치에 원 표시와 포인트 그림을 삽입했다. 공간 시각화를 할 때 임의로 표시하고 싶은 지점이 있을 때 이러한 기능을 사용한다.

# %%
# 서울 지도에 스타벅스 지점 수 시각화

m = folium.Map([37.541, 126.986], zoom_start=12 ,width="%100", height="%100")
locations = list(zip(df.latitude, df.longitude))
cluster = plugins.MarkerCluster(locations=locations,                     
               popups=df["name"].tolist())  
m.add_child(cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86eec52e00988cf9875eab708bd8a7ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86eec52e00988cf9875eab708bd8a7ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86eec52e00988cf9875eab708bd8a7ea = L.map(
#                 &quot;map_86eec52e00988cf9875eab708bd8a7ea&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53bf48387d4f98aa1c8725d6996b82aa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86eec52e00988cf9875eab708bd8a7ea);
#
#
#             var marker_cluster_b68861fa9f60a727131b8efc43703154 = L.markerClusterGroup(
#                 {}
#             );
#             map_86eec52e00988cf9875eab708bd8a7ea.addLayer(marker_cluster_b68861fa9f60a727131b8efc43703154);
#
#
#             var marker_97aa60b475affe0b01d3de51ac8d21f8 = L.marker(
#                 [37.5018592, 127.0372776],
#                 {}
#             ).addTo(marker_cluster_b68861fa9f60a727131b8efc43703154);
#
#
#         var popup_0805bed891ad4ce03b17f2b66ec0c812 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_950d2ebbe61b998ac6fa3b8fe6e4f368 = $(`&lt;div id=&quot;html_950d2ebbe61b998ac6fa3b8fe6e4f368&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GS타워&lt;/div&gt;`)[0];
#                 popup_0805bed891ad4ce03b17f2b66ec0c812.setContent(html_950d2ebbe61b998ac6fa3b8fe6e4f368);
#
#
#
#         marker_97aa60b475affe0b01d3de51ac8d21f8.bindPopup(popup_0805bed891ad4ce03b17f2b66ec0c812)
#         ;
#
#
#
#
#             var marker_dd9288f426d636eaba3787fbb9300694 = L.marker(
#                 [37.490298, 127.054895],
#                 {}
#             ).addTo(marker_cluster_b68861fa9f60a727131b8efc43703154);
#
#
#         var popup_bd713239348044ff2647963280e4fe90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5ee5e6e5967adbf700a86443e8a0732 = $(`&lt;div id=&quot;html_d5ee5e6e5967adbf700a86443e8a0732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SSG마켓도곡R&lt;/div&gt;`)[0];
#                 popup_bd713239348044ff2647963280e4fe90.setContent(html_d5ee5e6e5967adbf700a86443e8a0732);
#
#
#
#         marker_dd9288f426d636eaba3787fbb9300694.bindPopup(popup_bd713239348044ff2647963280e4fe90)
#         ;
#
#
#
#
#             var marker_cf62e06a9757c93f43582b5fc4e161b8 = L.marker(
#                 [37.47730499, 126.8876908],
#                 {}
#             ).addTo(marker_cluster_b68861fa9f60a727131b8efc43703154);
#
#
#         var popup_cbb0702c631cde3d6751d6e6f65e5443 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c312b0ae3c979913224ee4679203620c = $(`&lt;div id=&quot;html_c312b0ae3c979913224ee4679203620c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;W-Mall&lt;/div&gt;`)[0];
#                 popup_cbb0702c631cde3d6751d6e6f65e5443.setContent(html_c312b0ae3c979913224ee4679203620c);
#
#
#
#         marker_cf62e06a9757c93f43582b5fc4e161b8.bindPopup(popup_cbb0702c631cde3d6751d6e6f65e5443)
#         ;
#
#
#
#
#             var marker_caa81056bbea5b971706a982a163873e = L.marker(
#                 [37.4782316, 127.1193703],
#                 {}
#             ).addTo(marker_cluster_b68861fa9f60a727131b8efc43703154);
#
#
#         var popup_6f4e01f86f036e5401755e191eab858c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_898e630eda74bd6433395b0076ce8285 = $(`&lt;div id=&quot;html_898e630eda74bd6433395b0076ce8285&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가든파이브&lt;/div&gt;`)[0];
#                 popup_6f4e01f86f036e5401755e191eab858c.setContent(html_898e630eda74bd6433395b0076ce8285);
#
#
#
#         marker_caa81056bbea5b971706a982a163873e.bindPopup(popup_6f4e01f86f036e5401755e191eab858c)
#         ;
#
#
#
#
#             var marker_0a570c38348300d4988a9dd33b8cda94 = L.marker(
#                 [37.494895, 127.118785],
#                 {}
#             ).addTo(marker_cluster_b68861fa9f60a727131b8efc43703154);

# %% [markdown]
# 이제 앞에서 불러왔던 서울 지역의 스타벅스 위치 데이터를 지도 위에 표현한다. MarkerCluster() 함수는 각 구역에 존재하는 스타벅스 지점의 수를 숫자로 표현해 준다. 지도를 더 축소하면 원들이 뭉쳐 표현되면서 숫자들이 합해진다. 반대로 지도를 확대하면 원이 쪼개지다가 결국에는 하나의 핀으로 표현된다.

# %%
# 서울 지도에 스타벅스 지점수 도드맵 시각화

m = folium.Map(location=[37.541, 126.986], zoom_start=12, width="%100", height="%100")
locations = list(zip(df.latitude, df.longitude))
for i in range(len(locations)):
    folium.CircleMarker(location=locations[i],radius=1).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_480c17bd4ead2f72c5aeb5185771302b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_480c17bd4ead2f72c5aeb5185771302b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_480c17bd4ead2f72c5aeb5185771302b = L.map(
#                 &quot;map_480c17bd4ead2f72c5aeb5185771302b&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9ca5bae04f4a18253f9beab513096a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_480c17bd4ead2f72c5aeb5185771302b);
#
#
#             var circle_marker_1e123f5ccbcc96231209457b96d0665d = L.circleMarker(
#                 [37.5018592, 127.0372776],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_480c17bd4ead2f72c5aeb5185771302b);
#
#
#             var circle_marker_3155138d0e250dd6697d8b952ce14833 = L.circleMarker(
#                 [37.490298, 127.054895],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_480c17bd4ead2f72c5aeb5185771302b);
#
#
#             var circle_marker_00b3f0cebd7dfde9bf776a2cece9f29e = L.circleMarker(
#                 [37.47730499, 126.8876908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_480c17bd4ead2f72c5aeb5185771302b);
#
#
#             var circle_marker_8058931d2e08cc88fb4580eba06b0391 = L.circleMarker(
#                 [37.4782316, 127.1193703],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_480c17bd4ead2f72c5aeb5185771302b);
#
#
#             var circle_marker_2e0a4c04c63074273a95239494793a49 = L.circleMarker(
#                 [37.494895, 127.118785],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_480c17bd4ead2f72c5aeb5185771302b);
#
#
#             var circle_marker_29bc21634ac48f16eadbd51185a5c440 = L.circleMarker(
#                 [37.494299, 127.121354],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_480c17bd4ead2f72c5aeb5185771302b);
#
#
#             var circle_marker_b18bb4b35dda6e3cbab40162e7

# %% [markdown]
# 스타벅스 지점을 도트맵으로 시각화 했다. 서울 중심부와 강남 지역의 큰 길가 그리고 여의도에 매장이 집중되어 포진되어 있는 것을 확인할 수 있다.

# %%
# 서울 구 별 스타벅스 지점 수 집계 및 중심점 산출
df_m = df.groupby('gu_name').agg({'latitude':'mean',
                                  'longitude':'mean',
                                  'name':'count'}).reset_index()
df_m.head()
# Out:
#   gu_name   latitude   longitude  name
# 0     강남구  37.507603  127.044611    80
# 1     강동구  37.539914  127.137106    14
# 2     강북구  37.626866  127.026372     5
# 3     강서구  37.555716  126.841528    16
# 4     관악구  37.481759  126.944286    11

# %% [markdown]
# 다음으로 버블맵 시각화를 위해 데이터를 가공한다. 버블맵은 특정 지점에 지정된 수치의 값을 표현하기 때문에 기존 데이터를 구 단위로 집계해야 한다. 우선 gu_name 칼럼을 기준으로 latitude와 longitude의 평균값을 구하여 각 구의 중심 지점을 만든다. 그리고 스타벅스 지점명을 카운트하여 각 구에 포함되는 매장 수 합계를 구한다.

# %%
# 서울 구별 스타벅스 지점 수 버블맵 시각화

# 기본 지도 생성
m = folium.Map(location=[37.541, 126.986], tiles='Cartodb Positron', 
               zoom_start=11, width="%100", 
               height="%100")

# 구별 구분선, 색상 설정
folium.Choropleth(
    geo_data=geo, # 앞에서 불러온 json 파일 적용
    fill_color="gray"
    ).add_to(m)

# 버블맵 삽입
locations = list(zip(df_m.latitude, df_m.longitude))
for i in range(len(locations)):
    row = df_m.iloc[i]
    folium.CircleMarker(location=locations[i],
                        radius= float(row.name/2), # 버블 크기 설정
                        fill_color="blue"
                       ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49867d13401e381cc1c566122cd0809a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49867d13401e381cc1c566122cd0809a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49867d13401e381cc1c566122cd0809a = L.map(
#                 &quot;map_49867d13401e381cc1c566122cd0809a&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9954938673b41f3ddabf8e63b236458 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49867d13401e381cc1c566122cd0809a);
#
#
#             var choropleth_0cb6eb26b4eecdebda742951ab71b99a = L.featureGroup(
#                 {}
#             ).addTo(map_49867d13401e381cc1c566122cd0809a);
#
#
#         function geo_json_0ae1e7cd03b115880c9b3af959e70a9b_styler(feature) {
#             switch(feature.properties.SIG_CD) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0ae1e7cd03b115880c9b3af959e70a9b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0ae1e7cd03b115880c9b3af959e70a9b = L.geoJson(null, {
#                 onEachFeature: geo_json_0ae1e7cd03b115880c9b3af959e70a9b_onEachFeature,
#
#                 style: geo_json_0ae1e7cd03b115880c9b3af959e70a9b_styler,
#         });
#
#         function geo_json_0ae1e7cd03b115880c9b3af959e70a9b_add (data) {
#             geo_json_0ae1e7cd03b115880c9b3af959e70a9b
#                 .addData(data)
#                 .addTo(choropleth_0cb6eb26b4eecdebda742951ab71b99a);
#         }
#             geo_json_0ae1e7cd03b115880c9b3af959e70a9b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.012, 37.582], [127.015, 37.582], [127.016, 37.582], [127.017, 37.582], [127.017, 37.581], [127.017, 37.58], [127.018, 37.58], [127.018, 37.579], [127.018, 37.578], [127.019, 37.578], [127.02, 37.578], [127.019, 37.578], [127.02, 37.578], [127.02, 37.579], [127.021, 37.579], [127.022, 37.579], [127.023, 37.578], [127.023, 37.577], [127.023, 37.576], [127.023, 37.575], [127.023, 37.572], [127.018, 37.57], [127.015, 37.57], [127.001, 37.569], [126.997, 37.569], [126.99, 37.568], [126.976, 37.569], [126.969, 37.568], [126.967, 37.566], [126.954, 37.579], [126.957, 37.58], [126.958, 37.584], [126.958, 37.594], [126.958, 37.598], [126.953, 37.6], [126.954, 37.605], [126.951, 37.608], [126.95, 37.611], [126.951, 37.614], [126.949, 37.623], [126.95, 37.626], [126.958, 37.629], [126.964, 37.63], [126.966, 37.631], [126.973, 37.632], [126.975, 37.632], [126.975, 37.631], [126.976, 37.629], [126.977, 37.629], [126.978, 37.629], [126.979, 37.629], [126.98, 37.629], [126.98, 37.628], [126.982, 37.624], [126.984, 37.621], [126.985, 37.616], [126.985, 37.615], [126.987, 37.614], [126.986, 37.613], [126.987, 37.604], [126.986, 37.604], [126.986, 37.603], [126.983, 37.602], [126.981, 37.602], [126.98, 37.601], [126.979, 37.601], [126.978, 37.601], [126.978, 37.6], [126.977, 37.599], [126.977, 37.598], [126.978, 37.598], [126.978, 37.597], [126.979, 37.597], [126.979, 37.596], [126.981, 37.596], [126.981, 37.595], [126.982, 37.595], [126.983, 37.595], [126.984, 37.594], [126.985, 37.594], [126.986, 37.594], [126.986, 37.593], [126.987, 37.593], [126.988, 37.592], [126.989, 37.592], [126.994, 37.592], [126.995, 37.592], [126.996, 37.592], [126.997, 37.592], [126.998, 37.592], [126.999, 37.592], [127, 37.592], [127.001, 37.592], [127.002, 37.591], [127.001, 37.591], [127.001, 37.59], [127.002, 37.59], [127.002, 37.589], [127.003, 37.589], [127.003, 37.588], [127.004, 37.588], [127.007, 37.586], [127.007, 37.585], [127.007, 37.584], [127.007, 37.582], [127.008, 37.581], [127.012, 37.582]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;11110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jongno-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\ufffd\ufffd\ufffd\u03b1\ufffd&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.023, 37.572], [127.024, 37.567], [127.027, 37.563], [127.022, 37.558], [127.02, 37.557], [127.018, 37.557], [127.016, 37.553], [127.016, 37.552], [127.01, 37.548], [127.009, 37.544], [127.005, 37.546], [127.004, 37.55], [126.998, 37.55], [126.994, 37.547], [126.991, 37.551], [126.979, 37

# %% [markdown]
# 기본 지도에 Cartodb Positron 테마를 적용한 후에 앞에서 불러왔던 json 파일을 통해 구 별 경계선을 표현해 준다. 그리고 CircleMarker() 함수로 버블을 표현해 준다. 버블의 크기를 설정하는 radius=에 매장 수 합계 칼럼인 name을 설정해 주면 매장 수에 따라 버블의 크기가 달라진다. 그리고 버블의 크기가 너무 작아서 안보이거나 너무 커서 서로 겹치면 분모 값을 조정해 주면 된다.

# %%
# 미국 실업률 정보의 코로플레스맵 시각화를 위한 데이터, json 불러오기


url2="https://raw.githubusercontent.com/c-karl/DA_DS_Book001/main/datasets/us_states_unemployment.csv"
df2=pd.read_csv(url2)

# 주 별 경계 json 파일 불러오기
us_geo = 'https://raw.githubusercontent.com/c-karl/DA_DS_Book001/main/datasets/folium_us-states.json'

df2.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %% [markdown]
# 코로플레스맵은 구역에 따라 채도와 명도가 달라지도록 시각화 하는 방법이기 때문에 단순히 위도와 경도를 설정해서 만들 수 없다. 그래서 앞의 버블맵과 같이 json 파일의 미국 각 주 경계 값경곗값이 필요하다. 그리고 각 주의 위치는 불러온 테이블의 State 칼럼을 매칭해서 Unemployment 값을 표현해 준다.

# %%
# 미국 주별 실업률 코로플레스맵 시각화

# 미국 지도 시각화
m = folium.Map(location=[40,-98], zoom_start=3, tiles="Cartodb Positron")

# 지도에 주 경계선, 실업률 데이터 연동
m.choropleth(geo_data = us_geo, # json 데이터
               data = df2, # 실업률 데이터
               columns = ['State','Unemployment'], # 연동할 칼럼 설정
               key_on = 'feature.id', # json과 실업률 데이터를 연결할 키값 설정
               fill_color='YlGn',
               legend_name='실업률')

m
# Out:
# c:\Users\qksw5\anaconda3\envs\test\Lib\site-packages\folium\folium.py:465: FutureWarning:
#
# The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bd3272eae25bb7679ab7fa16302f172 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bd3272eae25bb7679ab7fa16302f172&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bd3272eae25bb7679ab7fa16302f172 = L.map(
#                 &quot;map_8bd3272eae25bb7679ab7fa16302f172&quot;,
#                 {
#                     center: [40.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67b4a47750a2bd24b372e2bc6ef4fb53 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8bd3272eae25bb7679ab7fa16302f172);
#
#
#             var choropleth_098d73b09ee717f9629c27287cb81852 = L.featureGroup(
#                 {}
#             ).addTo(map_8bd3272eae25bb7679ab7fa16302f172);
#
#
#         function geo_json_c36c5ee89043679bda2724b1c9666a65_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;NE&quot;: case &quot;ND&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c36c5ee89043679bda2724b1c9666a65_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c36c5ee89043679bda2724b1c9666a65 = L.geoJson(null, {
#                 onEachFeature: geo_json_c36c5ee89043679bda2724b1c9666a65_onEachFeature,
#
#                 style: geo_json_c36c5ee89043679bda2724b1c9666a65_styler,
#         });
#
#         function geo_json_c36c5ee89043679bda2724b1c9666a65_add (data) {
#             geo_json_c36c5ee89043679bda2724b1c9666a65
#                 .addData(data)
#                 .addTo(choropleth_098d73b09ee717f9629c27287cb81852);
#         }
#             geo_json_c36c5ee89043679bda2724b1c9666a65_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88

# %% [markdown]
# 기본 지도에 choropleth() 함수를 사용하여 json 데이터와 실업률 데이터를 적용한다. 데이터의 State 칼럼과 json 파일의 id 키 값을 매칭하도록 입력해 준다. 시각화한 결과를 보면 캘리포니아 지역과 노스 캐롤라이나 지역의 실업률이 높은 것을 직관적으로 확인할 수 있다.

# %%
# 서울과 각국의 수도 간의 커넥션맵 시각화

# 서울과 도쿄, 워싱턴, 마닐라, 파리, 모스크바 위경도 입력
source_to_dest = zip([37.541,37.541,37.541,37.541,37.541], 
                     [35.6804, 38.9072, 14.5995, 48.8566,55.7558],
                     [126.986,126.986,126.986,126.986,126.986], 
                     [139.7690, -77.0369, 120.9842, 2.3522,37.6173])

fig = go.Figure()

## for 문을 활용하여 위경도 입력
for a, b, c, d in source_to_dest:
    fig.add_trace(go.Scattergeo(
                        lat = [a, b],
                        lon = [c, d],
                        mode = 'lines',
                        line = dict(width = 1, color="red"),
                        opacity = 0.5 # 선 투명도
                        ))

fig.update_layout(
                margin={"t":0,"b":0,"l":0, "r":0, "pad":0},
                showlegend=False,
                geo = dict(
                showcountries=True) # 국가 경계선
                )

fig.show()

# %% [markdown]
# 커넥션맵은 graph_objects 패키지를 활용하여 테이블 없이 직접 위도와 경도를 입력해서 시각화 해보자. 시작점과 도착점의 위도, 경도를 입력하고 반복문으로 입력했던 모든 경로를 시각화 한다. 서울로부터 도쿄, 워싱턴, 마닐라, 파리, 그리고 모스크바로 연결된 선이 시각화 된 것을 확인할 수 있다.
